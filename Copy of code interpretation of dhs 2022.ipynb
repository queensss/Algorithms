# %%
# !pip install pyreadstat
# Out:
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-215/680804824.py in <cell line: 0>()
# ----> 1 get_ipython().system('pip install pyreadstat')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     151
#     152     if pip_warn:
# --> 153       _pip.print_previous_import_warning(output)
#     154
#     155   def _send_error(self, exc_content):
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in print_previous_import_warning(output)
#      54 def print_previous_import_warning(output):
#      55   """Prints a warning about previously imported packages."""
# ---> 56   packages = _previously_imported_packages(output)
#      57   if packages:
#      58     # display a list of packages using the colab-display-data mimetype, which
#
# ...

# %%
import pyreadstat
df, meta = pyreadstat.read_dta('/content/BDKR81FL.DTA')

# %%
"v705" in df.columns

# %%
df["v705"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v705"]  # father_occ

# %%
"v024" in df.columns

# %%
df["v024"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v024"] #division

# %%
"v116" in df.columns

# %%
df["v116"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v116"] # toilet type

# %%
"m15" in df.columns  # place delivery

# %%
df["m15"].value_counts(dropna=False)

# %%
meta.variable_value_labels["m15"] #place delivery

# %%
"v201" in df.columns

# %%
df["v201"].value_counts(dropna=False)

# %%
meta.column_names_to_labels["v201"]

# %%
"v121" in df.columns

# %%
df["v121"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v121"] # has tv

# %%
"v119" in df.columns

# %%
df["v119"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v119"] # has electricity

# %%
"v157" in df.columns

# %%
df["v157"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v157"] #  reads_newspaper

# %%
"m18" in df.columns

# %%
df["m18"].value_counts(dropna=False)

# %%
meta.variable_value_labels["m18"] # size_at_birth

# %%
"v602" in df.columns

# %%
df["v602"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v602"]

# %%
"v190" in df.columns

# %%
df["v190"].value_counts(dropna=False)

# %%
meta.variable_value_labels["v190"]

# %%
"b19" in df.columns

# %%
df["b19"].value_counts(dropna=False)

# %%
meta.column_names_to_labels["b19"]

# %%
"v445" in df.columns

# %%
df["v445"].value_counts(dropna=False)

# %%
meta.column_names_to_labels["v445"] # mother bmi

# %%
"b11" in df.columns

# %%
df["b11"].value_counts(dropna=False)

# %%
meta.column_names_to_labels["b11"]

# %%
meta.column_names_to_labels["v201"]

# %%
meta.column_names_to_labels["v012"] #mother age

# %%
"bord" in df.columns

# %%
meta.variable_to_label.get("bord")

# %%
df["bord"].describe()

# %%
df["bord"].value_counts().head(10)
